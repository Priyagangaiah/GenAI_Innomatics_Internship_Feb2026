# %%
# First USER LOGIN CHECK
correct_username = "admin"
correct_password = "1234"
username = input("Enter username: ")
password = input("Enter password: ")
if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %%
correct_username = "admin"
correct_password = "1234"
username = input("Enter username: ")
password = input("Enter password: ")
if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 12
# Invalid Credentials

# %%
#Second PASS/FAIL ANALYZER
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students:", len(marks))
print("Passed Students:", pass_count)
print("Failed Students:", fail_count)
# Out:
# Total Students: 5
# Passed Students: 3
# Failed Students: 2

# %%
#Third Simple Data Cleaner
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    cleaned = name.strip().lower()
    cleaned_names.append(cleaned)

print("Cleaned Names:", cleaned_names)
# Out:
# Cleaned Names: ['alice', 'bob', 'charlie']

# %%
#Fourth Message Length Analyze
messages = ["Hi", "Welcome to the platform", "OK"]

for msg in messages:
    length = len(msg)
    print(f"Message: '{msg}' | Length: {length}")

    if length > 10:
        print("This message is longer than 10 characters")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# This message is longer than 10 characters
# Message: 'OK' | Length: 2

# %%
#Fifth Error Message Detector
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = logs.count("ERROR")

print("Total ERROR entries:", error_count)
# Out:
# Total ERROR entries: 2
